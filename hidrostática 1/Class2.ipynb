# %% [markdown]
# # Eletrostática

# %% [markdown]
# É o...

# %% [markdown]
# É o estudo das cargas elétricas que não se encontram em movimento

# %% [markdown]
# A eletricidade é um fenômeno causado pelas cargas elétricas de prótons (+) e elétrons (-)

# %% [markdown]
# ![image.png](attachment:9bbe28dc-9815-43c7-a464-f8fa7a385c24.png)

# %% [markdown]
# $10^{-3}=0.001=\frac{1}{10^3}$

# %% [markdown]
# Carga do elétron (e próton) $1,6E-19$ ou $1,6 \, 10^{-19}$ Coulombs

# %% [markdown]
# ### Conservação das cargas elétricas

# %% [markdown]
# ## Campo elétrico

# %% [markdown]
# $E=k\frac{Q}{r^2}$ ... $k=8.99 \, 10^9 Nm^2/C^2$
#
# $F=k\frac{Q_1 Q_2 }{r^2}$ ... $k=8.99 \, 10^9 Nm^2/C^2$

# %% [markdown]
# ## Vetores

# %% [markdown]
# $V_1=(x_1, y_1)$
#
# $V_2=(x_2, y_1)$
#
# $V_1+V_2=(x_1+x_2, y_1+y_2)$

# %% [markdown]
# ## Tensão e corrente

# %% [markdown]
# Volt é a unidade de tensão <br>
# A corrente é medida em Amperes

# %% [markdown]
# $m v^2/2=K$
#
# $E_i=E_f$
#
# $1C/s=A$
#
# $1V 1A= 1V 1C/s = 1J/s=1W$

# %% [markdown]
# I=V/R  lei de Ohm

# %% [markdown]
# $R_{eq}=\frac{R_1R_2}{R_1+R_2}=\frac{RR}{R+R}$

# %% [markdown]
# $F=9\;10^{-5} N$
#
# $F/10^{-4}=a$

# %% [markdown]
# $M_i=M_f$

# %% [markdown]
# $(v_2 m_2,v_1 m_1) + m_3\,(v_{3x}, v_{3y})=0$
#
# $(vm)^2+(vm)^2=(m/2\,v_3)^2$
